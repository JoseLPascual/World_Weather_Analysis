# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the API key.
from config import weather_api_key

# %%
# 3. Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# 4. Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 784

# %%
# Import the requests library.
import requests

# 5. Starting URL for OpenWeatherMap API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)

# Import the datetime module from the datetime library.
from datetime import datetime
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8b89a50ca72377ea56cb819a8b6bb8d2

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
# for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
#    if (i % 50 == 0 and i >= 50):
#        set_count += 1
#        record_count = 1
    # Create endpoint URL with each city.
#    city_url = url + "&q=" + cities[i]

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # 6. Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | marawi
# Processing Record 4 of Set 1 | cootamundra
# Processing Record 5 of Set 1 | upernavik
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | karratha
# Processing Record 9 of Set 1 | east london
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | katherine
# Processing Record 12 of Set 1 | kennett
# Processing Record 13 of Set 1 | berlevag
# Processing Record 14 of Set 1 | bethanien
# Processing Record 15 of Set 1 | coahuayana
# Processing Record 16 of Set 1 | mount gambier
# Processing Record 17 of Set 1 | dharchula
# Processing Record 18 of Set 1 | hongan
# City not found. Skipping...
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | hithadhoo
# Processing Record 22 of Set 1 | bengkulu
# Processing Record 23 of Set 1 | faanui
# Processing Record 24 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 1 | pevek
# Processing Record 26 of Set 1 | avarua
# Processing Record 27 of Set 1 | katsuura
# Processing Record 28 of Set 1 | lebu
# Processing Record 29 of Set 1 | trairi
# Processing Record 30 of Set 1 | aykhal
# Processing Record 31 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 1 | burns lake
# Processing Record 33 of Set 1 | kahta
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | ishigaki
# Processing Record 36 of Set 1 | ocamonte
# Processing Record 37 of Set 1 | yellowknife
# Processing Record 38 of Set 1 | port elizabeth
# Processing Record 39 of Set 1 | ribeira grande
# Processing Record 40 of Set 1 | vung tau
# Processing Record 41 of Set 1 | jamestown
# Processing Record 42 of Set 1 | morant bay
# Processing Record 43 of Set 1 | albany
# Processing Record 44 of Set 1 | thompson
# Processing Record 45 of Set 1 | cherskiy
# Processing Record 46 of Set 1 | pandan
# Processing Record 47 of Set 1 | tuktoyaktuk
# Processing Record 48 of Set 1 | mayo
# Processing Record 49 of Set 1 | linxia
# Processing Record 50 of Set 1 | fort nelson
# Processing Record 1 of Set 2 | gardez
# Processing Record 2 of Set 2 | new norfolk
# Processing Record 3 of Set 2 | carauari
# Processing Record 4 of Set 2 | dergachi
# Processing Record 5 of Set 2 | ponta do sol
# Processing Record 6 of Set 2 | castro
# Processing Record 7 of Set 2 | gat
# Processing Record 8 of Set 2 | puerto ayora
# Processing Record 9 of Set 2 | hobart
# Processing Record 10 of Set 2 | leh
# Processing Record 11 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 12 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 2 | vila franca do campo
# Processing Record 14 of Set 2 | brigantine
# Processing Record 15 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 2 | bereda
# Processing Record 17 of Set 2 | kapaa
# Processing Record 18 of Set 2 | chake chake
# Processing Record 19 of Set 2 | chicama
# Processing Record 20 of Set 2 | west des moines
# Processing Record 21 of Set 2 | olinda
# Processing Record 22 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 2 | batagay
# Processing Record 24 of Set 2 | cape town
# Processing Record 25 of Set 2 | carnarvon
# Processing Record 26 of Set 2 | canto do buriti
# Processing Record 27 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 2 | klaksvik
# Processing Record 29 of Set 2 | tamandare
# Processing Record 30 of Set 2 | severo-kurilsk
# Processing Record 31 of Set 2 | maua
# Processing Record 32 of Set 2 | juazeiro
# Processing Record 33 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 2 | te anau
# Processing Record 35 of Set 2 | ambulu
# Processing Record 36 of Set 2 | mahebourg
# Processing Record 37 of Set 2 | tiksi
# Processing Record 38 of Set 2 | puerto penasco
# Processing Record 39 of Set 2 | khatanga
# Processing Record 40 of Set 2 | santa isabel do rio negro
# Processing Record 41 of Set 2 | sitamau
# Processing Record 42 of Set 2 | georgetown
# Processing Record 43 of Set 2 | zhigansk
# Processing Record 44 of Set 2 | bokspits
# City not found. Skipping...
# Processing Record 45 of Set 2 | kamenka
# Processing Record 46 of Set 2 | khandbari
# Processing Record 47 of Set 2 | hajipur
# Processing Record 48 of Set 2 | havre-saint-pierre
# Processing Record 49 of Set 2 | qaanaaq
# Processing Record 50 of Set 2 | kenai
# Processing Record 1 of Set 3 | clyde river
# Processing Record 2 of Set 3 | nadym
# Processing Record 3 of Set 3 | anta
# Processing Record 4 of Set 3 | barrow
# Processing Record 5 of Set 3 | bluff
# Processing Record 6 of Set 3 | saint anthony
# Processing Record 7 of Set 3 | souillac
# Processing Record 8 of Set 3 | hami
# Processing Record 9 of Set 3 | yulara
# Processing Record 10 of Set 3 | saskylakh
# Processing Record 11 of Set 3 | dingle
# Processing Record 12 of Set 3 | ankang
# Processing Record 13 of Set 3 | tasiilaq
# Processing Record 14 of Set 3 | broken hill
# Processing Record 15 of Set 3 | namie
# Processing Record 16 of Set 3 | araouane
# Processing Record 17 of Set 3 | simpang
# Processing Record 18 of Set 3 | san juan
# Processing Record 19 of Set 3 | faya
# Processing Record 20 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 21 of Set 3 | torbay
# Processing Record 22 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 3 | formosa
# Processing Record 24 of Set 3 | talnakh
# Processing Record 25 of Set 3 | phan thiet
# Processing Record 26 of Set 3 | mariinsk
# Processing Record 27 of Set 3 | chokurdakh
# Processing Record 28 of Set 3 | tahta
# Processing Record 29 of Set 3 | urcos
# Processing Record 30 of Set 3 | hermanus
# Processing Record 31 of Set 3 | helong
# Processing Record 32 of Set 3 | veraval
# Processing Record 33 of Set 3 | mar del plata
# Processing Record 34 of Set 3 | ampanihy
# Processing Record 35 of Set 3 | nakusp
# Processing Record 36 of Set 3 | bonito
# Processing Record 37 of Set 3 | bani walid
# Processing Record 38 of Set 3 | chornobay
# Processing Record 39 of Set 3 | henties bay
# Processing Record 40 of Set 3 | susehri
# Processing Record 41 of Set 3 | bethel
# Processing Record 42 of Set 3 | hilo
# Processing Record 43 of Set 3 | port alfred
# Processing Record 44 of Set 3 | impfondo
# Processing Record 45 of Set 3 | goderich
# Processing Record 46 of Set 3 | norman wells
# Processing Record 47 of Set 3 | jalu
# Processing Record 48 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 3 | guymon
# Processing Record 50 of Set 3 | ancud
# Processing Record 1 of Set 4 | ende
# Processing Record 2 of Set 4 | arcata
# Processing Record 3 of Set 4 | tarko-sale
# Processing Record 4 of Set 4 | mgandu
# Processing Record 5 of Set 4 | clarence town
# Processing Record 6 of Set 4 | epe
# Processing Record 7 of Set 4 | smoky lake
# Processing Record 8 of Set 4 | san rafael
# Processing Record 9 of Set 4 | bandarbeyla
# Processing Record 10 of Set 4 | kavieng
# Processing Record 11 of Set 4 | murillo
# Processing Record 12 of Set 4 | lidkoping
# Processing Record 13 of Set 4 | deputatskiy
# Processing Record 14 of Set 4 | isangel
# Processing Record 15 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 4 | khandyga
# Processing Record 17 of Set 4 | lorengau
# Processing Record 18 of Set 4 | gilbues
# Processing Record 19 of Set 4 | tiznit
# Processing Record 20 of Set 4 | zharkent
# Processing Record 21 of Set 4 | olafsvik
# Processing Record 22 of Set 4 | ahmadpur east
# Processing Record 23 of Set 4 | carbonia
# Processing Record 24 of Set 4 | rio branco
# Processing Record 25 of Set 4 | krasnoselkup
# Processing Record 26 of Set 4 | korla
# Processing Record 27 of Set 4 | nipawin
# Processing Record 28 of Set 4 | saint-joseph
# Processing Record 29 of Set 4 | baghdad
# Processing Record 30 of Set 4 | indio
# Processing Record 31 of Set 4 | namtsy
# Processing Record 32 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 33 of Set 4 | yurimaguas
# Processing Record 34 of Set 4 | avera
# Processing Record 35 of Set 4 | wilmington
# Processing Record 36 of Set 4 | carbondale
# Processing Record 37 of Set 4 | yarmouth
# Processing Record 38 of Set 4 | pisco
# Processing Record 39 of Set 4 | gazanjyk
# Processing Record 40 of Set 4 | puerto cabello
# Processing Record 41 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 4 | tura
# Processing Record 43 of Set 4 | praia da vitoria
# Processing Record 44 of Set 4 | santa fe
# Processing Record 45 of Set 4 | russkiy aktash
# Processing Record 46 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 4 | rawson
# Processing Record 48 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 4 | victoria
# Processing Record 50 of Set 4 | lamu
# Processing Record 1 of Set 5 | tilichiki
# Processing Record 2 of Set 5 | villaviciosa
# Processing Record 3 of Set 5 | nhulunbuy
# Processing Record 4 of Set 5 | kapiri mposhi
# Processing Record 5 of Set 5 | misratah
# Processing Record 6 of Set 5 | limoges
# Processing Record 7 of Set 5 | samfya
# Processing Record 8 of Set 5 | iquitos
# Processing Record 9 of Set 5 | elk grove
# Processing Record 10 of Set 5 | chernyshkovskiy
# Processing Record 11 of Set 5 | omboue
# Processing Record 12 of Set 5 | esperance
# Processing Record 13 of Set 5 | vao
# Processing Record 14 of Set 5 | sergeyevka
# Processing Record 15 of Set 5 | dawei
# Processing Record 16 of Set 5 | ilulissat
# Processing Record 17 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 5 | kodiak
# Processing Record 19 of Set 5 | komsomolskiy
# Processing Record 20 of Set 5 | roma
# Processing Record 21 of Set 5 | nikolskoye
# Processing Record 22 of Set 5 | salym
# Processing Record 23 of Set 5 | tutoia
# Processing Record 24 of Set 5 | katobu
# Processing Record 25 of Set 5 | zhob
# Processing Record 26 of Set 5 | bataipora
# Processing Record 27 of Set 5 | gamba
# Processing Record 28 of Set 5 | mana
# Processing Record 29 of Set 5 | gualaceo
# Processing Record 30 of Set 5 | west wendover
# Processing Record 31 of Set 5 | flinders
# Processing Record 32 of Set 5 | lokot
# Processing Record 33 of Set 5 | saint-pierre
# Processing Record 34 of Set 5 | borogontsy
# Processing Record 35 of Set 5 | aldan
# Processing Record 36 of Set 5 | antsohihy
# Processing Record 37 of Set 5 | canton
# Processing Record 38 of Set 5 | leningradskiy
# Processing Record 39 of Set 5 | mayumba
# Processing Record 40 of Set 5 | podgorica
# Processing Record 41 of Set 5 | champerico
# Processing Record 42 of Set 5 | nome
# Processing Record 43 of Set 5 | butaritari
# Processing Record 44 of Set 5 | mandera
# Processing Record 45 of Set 5 | manyana
# Processing Record 46 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 47 of Set 5 | loralai
# Processing Record 48 of Set 5 | benguela
# Processing Record 49 of Set 5 | barinas
# Processing Record 50 of Set 5 | toamasina
# Processing Record 1 of Set 6 | pangnirtung
# Processing Record 2 of Set 6 | baturaja
# Processing Record 3 of Set 6 | rocha
# Processing Record 4 of Set 6 | airai
# Processing Record 5 of Set 6 | weligama
# Processing Record 6 of Set 6 | taoudenni
# Processing Record 7 of Set 6 | okhotsk
# Processing Record 8 of Set 6 | cayenne
# Processing Record 9 of Set 6 | tocopilla
# Processing Record 10 of Set 6 | san policarpo
# Processing Record 11 of Set 6 | coihaique
# Processing Record 12 of Set 6 | urumqi
# Processing Record 13 of Set 6 | garcia hernandez
# Processing Record 14 of Set 6 | paoua
# Processing Record 15 of Set 6 | bilibino
# Processing Record 16 of Set 6 | kholm
# Processing Record 17 of Set 6 | jeremie
# Processing Record 18 of Set 6 | saint-philippe
# Processing Record 19 of Set 6 | shimanovsk
# Processing Record 20 of Set 6 | klyuchi
# Processing Record 21 of Set 6 | alta floresta
# Processing Record 22 of Set 6 | zihuatanejo
# Processing Record 23 of Set 6 | tangping
# Processing Record 24 of Set 6 | port hawkesbury
# Processing Record 25 of Set 6 | tapaua
# City not found. Skipping...
# Processing Record 26 of Set 6 | chiang khong
# Processing Record 27 of Set 6 | makasar
# Processing Record 28 of Set 6 | curup
# Processing Record 29 of Set 6 | maragogi
# Processing Record 30 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 6 | puerto cabezas
# Processing Record 32 of Set 6 | naryan-mar
# Processing Record 33 of Set 6 | bambous virieux
# Processing Record 34 of Set 6 | nassau
# Processing Record 35 of Set 6 | cabo san lucas
# Processing Record 36 of Set 6 | portland
# Processing Record 37 of Set 6 | vardo
# Processing Record 38 of Set 6 | tupik
# Processing Record 39 of Set 6 | sabha
# Processing Record 40 of Set 6 | hirara
# Processing Record 41 of Set 6 | amapa
# Processing Record 42 of Set 6 | dikson
# Processing Record 43 of Set 6 | corinto
# Processing Record 44 of Set 6 | dalbandin
# Processing Record 45 of Set 6 | abha
# Processing Record 46 of Set 6 | high prairie
# Processing Record 47 of Set 6 | khasan
# Processing Record 48 of Set 6 | hasaki
# Processing Record 49 of Set 6 | sur
# Processing Record 50 of Set 6 | cockburn town
# Processing Record 1 of Set 7 | muyezerskiy
# Processing Record 2 of Set 7 | manono
# Processing Record 3 of Set 7 | beringovskiy
# Processing Record 4 of Set 7 | muros
# Processing Record 5 of Set 7 | cidreira
# Processing Record 6 of Set 7 | provideniya
# Processing Record 7 of Set 7 | hovd
# Processing Record 8 of Set 7 | dunedin
# Processing Record 9 of Set 7 | sola
# Processing Record 10 of Set 7 | nago
# Processing Record 11 of Set 7 | huamachuco
# Processing Record 12 of Set 7 | paramonga
# Processing Record 13 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 14 of Set 7 | kalabo
# Processing Record 15 of Set 7 | nouakchott
# Processing Record 16 of Set 7 | fortuna
# Processing Record 17 of Set 7 | mehamn
# Processing Record 18 of Set 7 | mikkeli
# Processing Record 19 of Set 7 | palmer
# Processing Record 20 of Set 7 | skjaerhollen
# City not found. Skipping...
# Processing Record 21 of Set 7 | fairbanks
# Processing Record 22 of Set 7 | luderitz
# Processing Record 23 of Set 7 | frontera
# Processing Record 24 of Set 7 | yanchukan
# City not found. Skipping...
# Processing Record 25 of Set 7 | yagodnoye
# Processing Record 26 of Set 7 | torrington
# Processing Record 27 of Set 7 | riyadh
# Processing Record 28 of Set 7 | mutsamudu
# City not found. Skipping...
# Processing Record 29 of Set 7 | huilong
# Processing Record 30 of Set 7 | usogorsk
# Processing Record 31 of Set 7 | rapid valley
# Processing Record 32 of Set 7 | suining
# Processing Record 33 of Set 7 | andenes
# Processing Record 34 of Set 7 | maloy
# Processing Record 35 of Set 7 | manado
# Processing Record 36 of Set 7 | galesong
# Processing Record 37 of Set 7 | shache
# Processing Record 38 of Set 7 | tvoroyri
# Processing Record 39 of Set 7 | sobolevo
# Processing Record 40 of Set 7 | bathsheba
# Processing Record 41 of Set 7 | iqaluit
# Processing Record 42 of Set 7 | joao pinheiro
# Processing Record 43 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 7 | duz
# City not found. Skipping...
# Processing Record 45 of Set 7 | litayen
# City not found. Skipping...
# Processing Record 46 of Set 7 | leticia
# Processing Record 47 of Set 7 | sao jose da coroa grande
# Processing Record 48 of Set 7 | mabaruma
# Processing Record 49 of Set 7 | mezen
# Processing Record 50 of Set 7 | bulungu
# Processing Record 1 of Set 8 | moiyabana
# City not found. Skipping...
# Processing Record 2 of Set 8 | chuy
# Processing Record 3 of Set 8 | valencia
# Processing Record 4 of Set 8 | tromso
# Processing Record 5 of Set 8 | uruzgan
# Processing Record 6 of Set 8 | sao paulo de olivenca
# Processing Record 7 of Set 8 | high rock
# Processing Record 8 of Set 8 | buraydah
# Processing Record 9 of Set 8 | westport
# Processing Record 10 of Set 8 | rosetta
# Processing Record 11 of Set 8 | la ronge
# Processing Record 12 of Set 8 | lompoc
# Processing Record 13 of Set 8 | quito
# Processing Record 14 of Set 8 | longyearbyen
# Processing Record 15 of Set 8 | liwale
# Processing Record 16 of Set 8 | vestmannaeyjar
# Processing Record 17 of Set 8 | san jose
# Processing Record 18 of Set 8 | kalach-na-donu
# Processing Record 19 of Set 8 | aksarka
# Processing Record 20 of Set 8 | notre-dame-du-lac
# Processing Record 21 of Set 8 | soure
# Processing Record 22 of Set 8 | luba
# Processing Record 23 of Set 8 | auki
# Processing Record 24 of Set 8 | tungkang
# City not found. Skipping...
# Processing Record 25 of Set 8 | narsaq
# Processing Record 26 of Set 8 | constitucion
# Processing Record 27 of Set 8 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 28 of Set 8 | novyy urengoy
# Processing Record 29 of Set 8 | college
# Processing Record 30 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 8 | morgan city
# Processing Record 32 of Set 8 | los llanos de aridane
# Processing Record 33 of Set 8 | lodja
# Processing Record 34 of Set 8 | puerto varas
# Processing Record 35 of Set 8 | pasuruan
# Processing Record 36 of Set 8 | codrington
# Processing Record 37 of Set 8 | macheng
# Processing Record 38 of Set 8 | sikonge
# Processing Record 39 of Set 8 | tala
# Processing Record 40 of Set 8 | eskil
# Processing Record 41 of Set 8 | grand-bourg
# Processing Record 42 of Set 8 | arraial do cabo
# Processing Record 43 of Set 8 | nabire
# Processing Record 44 of Set 8 | pimentel
# Processing Record 45 of Set 8 | tual
# Processing Record 46 of Set 8 | havelock
# Processing Record 47 of Set 8 | shingu
# Processing Record 48 of Set 8 | mount isa
# Processing Record 49 of Set 8 | odweyne
# Processing Record 50 of Set 8 | asau
# Processing Record 1 of Set 9 | guerrero negro
# Processing Record 2 of Set 9 | green river
# Processing Record 3 of Set 9 | port shepstone
# Processing Record 4 of Set 9 | isla vista
# Processing Record 5 of Set 9 | abu kamal
# Processing Record 6 of Set 9 | robertsport
# Processing Record 7 of Set 9 | husavik
# Processing Record 8 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 10 of Set 9 | ukiah
# Processing Record 11 of Set 9 | canutama
# Processing Record 12 of Set 9 | werda
# Processing Record 13 of Set 9 | caernarfon
# Processing Record 14 of Set 9 | yurkivka
# Processing Record 15 of Set 9 | port augusta
# Processing Record 16 of Set 9 | hermsdorf
# Processing Record 17 of Set 9 | gornyak
# Processing Record 18 of Set 9 | mogocha
# Processing Record 19 of Set 9 | benghazi
# Processing Record 20 of Set 9 | dzilam gonzalez
# Processing Record 21 of Set 9 | batonyterenye
# Processing Record 22 of Set 9 | inuvik
# Processing Record 23 of Set 9 | alexandria
# Processing Record 24 of Set 9 | hervey bay
# Processing Record 25 of Set 9 | atakpame
# Processing Record 26 of Set 9 | saldanha
# Processing Record 27 of Set 9 | seoul
# Processing Record 28 of Set 9 | perth
# Processing Record 29 of Set 9 | palauig
# Processing Record 30 of Set 9 | amga
# Processing Record 31 of Set 9 | kavaratti
# Processing Record 32 of Set 9 | konya
# Processing Record 33 of Set 9 | haikou
# Processing Record 34 of Set 9 | ballina
# Processing Record 35 of Set 9 | wamba
# Processing Record 36 of Set 9 | udachnyy
# Processing Record 37 of Set 9 | alice springs
# Processing Record 38 of Set 9 | sept-iles
# Processing Record 39 of Set 9 | do gonbadan
# Processing Record 40 of Set 9 | chinchani
# Processing Record 41 of Set 9 | sao felix do xingu
# Processing Record 42 of Set 9 | lukovit
# Processing Record 43 of Set 9 | khor
# Processing Record 44 of Set 9 | ialibu
# Processing Record 45 of Set 9 | durango
# Processing Record 46 of Set 9 | hamilton
# Processing Record 47 of Set 9 | rudbar
# Processing Record 48 of Set 9 | aktau
# Processing Record 49 of Set 9 | namibe
# Processing Record 50 of Set 9 | makakilo city
# Processing Record 1 of Set 10 | grand island
# Processing Record 2 of Set 10 | matara
# Processing Record 3 of Set 10 | nantucket
# Processing Record 4 of Set 10 | suntar
# Processing Record 5 of Set 10 | rorvik
# Processing Record 6 of Set 10 | burica
# City not found. Skipping...
# Processing Record 7 of Set 10 | balimo
# City not found. Skipping...
# Processing Record 8 of Set 10 | kaitangata
# Processing Record 9 of Set 10 | tuatapere
# Processing Record 10 of Set 10 | westpunt
# City not found. Skipping...
# Processing Record 11 of Set 10 | luena
# Processing Record 12 of Set 10 | homer
# Processing Record 13 of Set 10 | abeche
# Processing Record 14 of Set 10 | batticaloa
# Processing Record 15 of Set 10 | kutum
# Processing Record 16 of Set 10 | mogadishu
# Processing Record 17 of Set 10 | port hedland
# Processing Record 18 of Set 10 | beloha
# Processing Record 19 of Set 10 | harrogate
# Processing Record 20 of Set 10 | waw
# Processing Record 21 of Set 10 | sao filipe
# Processing Record 22 of Set 10 | taiyuan
# Processing Record 23 of Set 10 | salalah
# Processing Record 24 of Set 10 | mpika
# Processing Record 25 of Set 10 | albania
# Processing Record 26 of Set 10 | margate
# Processing Record 27 of Set 10 | pontianak
# Processing Record 28 of Set 10 | winder
# Processing Record 29 of Set 10 | mongo
# Processing Record 30 of Set 10 | egvekinot
# Processing Record 31 of Set 10 | bonthe
# Processing Record 32 of Set 10 | kupang
# Processing Record 33 of Set 10 | tautira
# Processing Record 34 of Set 10 | namatanai
# Processing Record 35 of Set 10 | altamira
# Processing Record 36 of Set 10 | keetmanshoop
# Processing Record 37 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 38 of Set 10 | wanaka
# Processing Record 39 of Set 10 | chara
# Processing Record 40 of Set 10 | batagay-alyta
# Processing Record 41 of Set 10 | kabalo
# Processing Record 42 of Set 10 | xam nua
# Processing Record 43 of Set 10 | geraldton
# Processing Record 44 of Set 10 | gainesville
# Processing Record 45 of Set 10 | gobabis
# Processing Record 46 of Set 10 | pochutla
# Processing Record 47 of Set 10 | feira de santana
# Processing Record 48 of Set 10 | tommot
# Processing Record 49 of Set 10 | tigzirt
# Processing Record 50 of Set 10 | tiruvottiyur
# City not found. Skipping...
# Processing Record 1 of Set 11 | naze
# Processing Record 2 of Set 11 | sinjar
# Processing Record 3 of Set 11 | kaputa
# Processing Record 4 of Set 11 | uzumlu
# City not found. Skipping...
# Processing Record 5 of Set 11 | coquimbo
# Processing Record 6 of Set 11 | jucurutu
# Processing Record 7 of Set 11 | adre
# Processing Record 8 of Set 11 | northam
# Processing Record 9 of Set 11 | redcar
# Processing Record 10 of Set 11 | san cristobal
# Processing Record 11 of Set 11 | mitsamiouli
# Processing Record 12 of Set 11 | adrar
# Processing Record 13 of Set 11 | victor harbor
# Processing Record 14 of Set 11 | channel-port aux basques
# Processing Record 15 of Set 11 | tucurui
# Processing Record 16 of Set 11 | kaminokawa
# Processing Record 17 of Set 11 | zabaykalsk
# Processing Record 18 of Set 11 | mastic beach
# Processing Record 19 of Set 11 | cortez
# Processing Record 20 of Set 11 | malinovoye ozero
# Processing Record 21 of Set 11 | comodoro rivadavia
# Processing Record 22 of Set 11 | cap malheureux
# Processing Record 23 of Set 11 | bushehr
# Processing Record 24 of Set 11 | labuhan
# Processing Record 25 of Set 11 | axim
# Processing Record 26 of Set 11 | hobyo
# Processing Record 27 of Set 11 | paraopeba
# Processing Record 28 of Set 11 | paragominas
# Processing Record 29 of Set 11 | port pirie
# Processing Record 30 of Set 11 | moose factory
# Processing Record 31 of Set 11 | parana
# Processing Record 32 of Set 11 | grand gaube
# Processing Record 33 of Set 11 | saint george
# Processing Record 34 of Set 11 | raymondville
# Processing Record 35 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 36 of Set 11 | abdulino
# Processing Record 37 of Set 11 | mersing
# Processing Record 38 of Set 11 | ostrovnoy
# Processing Record 39 of Set 11 | hurghada
# Processing Record 40 of Set 11 | abaza
# Processing Record 41 of Set 11 | aklavik
# Processing Record 42 of Set 11 | nyurba
# Processing Record 43 of Set 11 | ambagarh chauki
# Processing Record 44 of Set 11 | taltal
# Processing Record 45 of Set 11 | lobito
# Processing Record 46 of Set 11 | mtsensk
# Processing Record 47 of Set 11 | valdivia
# Processing Record 48 of Set 11 | ahuimanu
# Processing Record 49 of Set 11 | abu samrah
# Processing Record 50 of Set 11 | belaya gora
# Processing Record 1 of Set 12 | matadi
# Processing Record 2 of Set 12 | plettenberg bay
# Processing Record 3 of Set 12 | nuuk
# Processing Record 4 of Set 12 | sao tome
# Processing Record 5 of Set 12 | tabuk
# Processing Record 6 of Set 12 | great yarmouth
# Processing Record 7 of Set 12 | lasa
# Processing Record 8 of Set 12 | ulagan
# Processing Record 9 of Set 12 | kudahuvadhoo
# Processing Record 10 of Set 12 | yar-sale
# Processing Record 11 of Set 12 | vagur
# Processing Record 12 of Set 12 | silopi
# Processing Record 13 of Set 12 | nador
# Processing Record 14 of Set 12 | la paz
# Processing Record 15 of Set 12 | kushima
# Processing Record 16 of Set 12 | araguatins
# City not found. Skipping...
# Processing Record 17 of Set 12 | bondo
# Processing Record 18 of Set 12 | saurimo
# Processing Record 19 of Set 12 | srivardhan
# Processing Record 20 of Set 12 | batemans bay
# Processing Record 21 of Set 12 | pangody
# Processing Record 22 of Set 12 | touros
# Processing Record 23 of Set 12 | grand-santi
# Processing Record 24 of Set 12 | meiganga
# Processing Record 25 of Set 12 | san patricio
# Processing Record 26 of Set 12 | la sarre
# Processing Record 27 of Set 12 | havoysund
# Processing Record 28 of Set 12 | kidal
# Processing Record 29 of Set 12 | magadan
# Processing Record 30 of Set 12 | kokoda
# Processing Record 31 of Set 12 | rostovka
# Processing Record 32 of Set 12 | bilma
# Processing Record 33 of Set 12 | kalmunai
# Processing Record 34 of Set 12 | beian
# Processing Record 35 of Set 12 | phrai bung
# City not found. Skipping...
# Processing Record 36 of Set 12 | lazaro cardenas
# Processing Record 37 of Set 12 | broome
# Processing Record 38 of Set 12 | grindavik
# Processing Record 39 of Set 12 | alofi
# Processing Record 40 of Set 12 | bocaiuva
# Processing Record 41 of Set 12 | kruisfontein
# Processing Record 42 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 12 | teguise
# Processing Record 44 of Set 12 | ingham
# Processing Record 45 of Set 12 | buritis
# Processing Record 46 of Set 12 | atar
# Processing Record 47 of Set 12 | naron
# Processing Record 48 of Set 12 | quetigny
# Processing Record 49 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 50 of Set 12 | morros
# Processing Record 1 of Set 13 | richmond
# Processing Record 2 of Set 13 | teguldet
# Processing Record 3 of Set 13 | newport
# Processing Record 4 of Set 13 | aquiraz
# Processing Record 5 of Set 13 | inhambane
# Processing Record 6 of Set 13 | sorong
# Processing Record 7 of Set 13 | yebaishou
# Processing Record 8 of Set 13 | barsi
# Processing Record 9 of Set 13 | elko
# Processing Record 10 of Set 13 | gimli
# Processing Record 11 of Set 13 | lokosovo
# Processing Record 12 of Set 13 | ulaanbaatar
# Processing Record 13 of Set 13 | verkhnyaya toyma
# Processing Record 14 of Set 13 | caravelas
# Processing Record 15 of Set 13 | jhargram
# Processing Record 16 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 17 of Set 13 | umm durman
# City not found. Skipping...
# Processing Record 18 of Set 13 | gualeguay
# Processing Record 19 of Set 13 | galiwinku
# City not found. Skipping...
# Processing Record 20 of Set 13 | parksepa
# Processing Record 21 of Set 13 | nkowakowa
# Processing Record 22 of Set 13 | moussoro
# Processing Record 23 of Set 13 | royan
# Processing Record 24 of Set 13 | kahului
# Processing Record 25 of Set 13 | mwinilunga
# Processing Record 26 of Set 13 | buala
# Processing Record 27 of Set 13 | ambon
# Processing Record 28 of Set 13 | abu dhabi
# Processing Record 29 of Set 13 | yerbogachen
# Processing Record 30 of Set 13 | nanortalik
# Processing Record 31 of Set 13 | andevoranto
# City not found. Skipping...
# Processing Record 32 of Set 13 | kuching
# Processing Record 33 of Set 13 | port-gentil
# Processing Record 34 of Set 13 | srednekolymsk
# Processing Record 35 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 36 of Set 13 | barcarena
# Processing Record 37 of Set 13 | svetlyy
# Processing Record 38 of Set 13 | kinablangan
# Processing Record 39 of Set 13 | wuda
# Processing Record 40 of Set 13 | machico
# Processing Record 41 of Set 13 | kerouane
# Processing Record 42 of Set 13 | yaan
# Processing Record 43 of Set 13 | pyu
# Processing Record 44 of Set 13 | fereydun kenar
# Processing Record 45 of Set 13 | la roda
# Processing Record 46 of Set 13 | huaicheng
# Processing Record 47 of Set 13 | ahipara
# Processing Record 48 of Set 13 | filadelfia
# Processing Record 49 of Set 13 | fort frances
# Processing Record 50 of Set 13 | talawdi
# City not found. Skipping...
# Processing Record 1 of Set 14 | dukat
# Processing Record 2 of Set 14 | otavi
# Processing Record 3 of Set 14 | poum
# Processing Record 4 of Set 14 | corpus christi
# Processing Record 5 of Set 14 | lumut
# Processing Record 6 of Set 14 | padang
# Processing Record 7 of Set 14 | coari
# Processing Record 8 of Set 14 | byron bay
# Processing Record 9 of Set 14 | yakeshi
# Processing Record 10 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 11 of Set 14 | monrovia
# Processing Record 12 of Set 14 | rab
# City not found. Skipping...
# Processing Record 13 of Set 14 | cavalcante
# Processing Record 14 of Set 14 | olds
# Processing Record 15 of Set 14 | evensk
# Processing Record 16 of Set 14 | muzhi
# Processing Record 17 of Set 14 | sydney mines
# Processing Record 18 of Set 14 | jabiru
# City not found. Skipping...
# Processing Record 19 of Set 14 | krutinka
# Processing Record 20 of Set 14 | lumeje
# Processing Record 21 of Set 14 | lesnikovo
# Processing Record 22 of Set 14 | sao joao da barra
# Processing Record 23 of Set 14 | illela
# Processing Record 24 of Set 14 | baherden
# Processing Record 25 of Set 14 | syracuse
# Processing Record 26 of Set 14 | praia
# Processing Record 27 of Set 14 | yamada
# Processing Record 28 of Set 14 | erenhot
# Processing Record 29 of Set 14 | noumea
# Processing Record 30 of Set 14 | conneaut
# Processing Record 31 of Set 14 | fenton
# Processing Record 32 of Set 14 | kloulklubed
# Processing Record 33 of Set 14 | turukhansk
# Processing Record 34 of Set 14 | jurm
# Processing Record 35 of Set 14 | pontal do parana
# Processing Record 36 of Set 14 | acapulco
# Processing Record 37 of Set 14 | saryshagan
# City not found. Skipping...
# Processing Record 38 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 39 of Set 14 | male
# Processing Record 40 of Set 14 | liaoyang
# Processing Record 41 of Set 14 | anito
# Processing Record 42 of Set 14 | mandya
# Processing Record 43 of Set 14 | oda
# Processing Record 44 of Set 14 | ust-omchug
# Processing Record 45 of Set 14 | ust-tsilma
# Processing Record 46 of Set 14 | huarmey
# Processing Record 47 of Set 14 | sidney
# Processing Record 48 of Set 14 | loukhi
# Processing Record 49 of Set 14 | yantal
# Processing Record 50 of Set 14 | nyrob
# Processing Record 1 of Set 15 | acurenam
# Processing Record 2 of Set 15 | uyuni
# Processing Record 3 of Set 15 | bagalkot
# Processing Record 4 of Set 15 | tarboro
# Processing Record 5 of Set 15 | bayan
# Processing Record 6 of Set 15 | port hardy
# Processing Record 7 of Set 15 | bandar-e lengeh
# Processing Record 8 of Set 15 | mapiripan
# Processing Record 9 of Set 15 | puerto baquerizo moreno
# Processing Record 10 of Set 15 | khani
# Processing Record 11 of Set 15 | punto fijo
# Processing Record 12 of Set 15 | kedrovyy
# Processing Record 13 of Set 15 | monte alegre
# Processing Record 14 of Set 15 | khryashchevka
# Processing Record 15 of Set 15 | thinadhoo
# Processing Record 16 of Set 15 | sinnamary
# Processing Record 17 of Set 15 | kununurra
# Processing Record 18 of Set 15 | djenne
# Processing Record 19 of Set 15 | sioux lookout
# Processing Record 20 of Set 15 | dillon
# Processing Record 21 of Set 15 | ranong
# Processing Record 22 of Set 15 | mahaicony
# City not found. Skipping...
# Processing Record 23 of Set 15 | el tigre
# Processing Record 24 of Set 15 | bara
# Processing Record 25 of Set 15 | vila velha
# Processing Record 26 of Set 15 | parakou
# Processing Record 27 of Set 15 | meulaboh
# Processing Record 28 of Set 15 | iskateley
# Processing Record 29 of Set 15 | nichinan
# Processing Record 30 of Set 15 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 31 of Set 15 | kungurtug
# Processing Record 32 of Set 15 | nunoa
# Processing Record 33 of Set 15 | imeni poliny osipenko
# Processing Record 34 of Set 15 | bartica
# Processing Record 35 of Set 15 | cabras
# Processing Record 36 of Set 15 | nelson bay
# Processing Record 37 of Set 15 | gambela
# Processing Record 38 of Set 15 | capaci
# Processing Record 39 of Set 15 | biak
# Processing Record 40 of Set 15 | leeton
# Processing Record 41 of Set 15 | camacha
# Processing Record 42 of Set 15 | dauphin
# Processing Record 43 of Set 15 | ivankiv
# Processing Record 44 of Set 15 | beceni
# Processing Record 45 of Set 15 | itarema
# Processing Record 46 of Set 15 | usta muhammad
# Processing Record 47 of Set 15 | labuan
# Processing Record 48 of Set 15 | fukue
# Processing Record 49 of Set 15 | sangar
# Processing Record 50 of Set 15 | berdigestyakh
# Processing Record 1 of Set 16 | ponta delgada
# Processing Record 2 of Set 16 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 16 | karatuzskoye
# Processing Record 4 of Set 16 | ola
# Processing Record 5 of Set 16 | vostok
# Processing Record 6 of Set 16 | kostek
# Processing Record 7 of Set 16 | kashi
# Processing Record 8 of Set 16 | port blair
# Processing Record 9 of Set 16 | lahaina
# Processing Record 10 of Set 16 | stephenville
# Processing Record 11 of Set 16 | ucluelet
# Processing Record 12 of Set 16 | panzhihua
# Processing Record 13 of Set 16 | soyaux
# Processing Record 14 of Set 16 | moengo
# Processing Record 15 of Set 16 | yazd
# Processing Record 16 of Set 16 | khorixas
# Processing Record 17 of Set 16 | general elizardo aquino
# Processing Record 18 of Set 16 | beira
# Processing Record 19 of Set 16 | muravlenko
# Processing Record 20 of Set 16 | kitovo
# Processing Record 21 of Set 16 | kentwood
# Processing Record 22 of Set 16 | ndago
# Processing Record 23 of Set 16 | vsevolozhsk
# Processing Record 24 of Set 16 | haines junction
# Processing Record 25 of Set 16 | chancay
# Processing Record 26 of Set 16 | mon
# Processing Record 27 of Set 16 | florin
# Processing Record 28 of Set 16 | abu zabad
# Processing Record 29 of Set 16 | onega
# Processing Record 30 of Set 16 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 16 | port lincoln
# Processing Record 32 of Set 16 | moundou
# Processing Record 33 of Set 16 | belyy yar
# Processing Record 34 of Set 16 | pathein
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# 7. Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng Current Description  Max Temp  Humidity  \
# 0       Ushuaia -54.8000  -68.3000       broken clouds     28.06       100
# 1  Punta Arenas -53.1500  -70.9167       broken clouds     33.91        69
# 2        Marawi   7.9986  124.2928     overcast clouds     67.64        91
# 3   Cootamundra -34.6500  148.0333           clear sky     48.94        54
# 4     Upernavik  72.7868  -56.1549     overcast clouds     31.60        93
# 5     Busselton -33.6500  115.3333     overcast clouds     51.08        68
# 6        Atuona  -9.8000 -139.0333           clear sky     79.56        64
# 7      Karratha -20.7377  116.8463           clear sky     67.82        69
# 8   East London -33.0153   27.9116     overcast clouds     56.59        65
# 9       Mataura -46.1927  168.8643          light rain     49.48        98
#
#    Cloudiness  Wind Speed Country
# 0          75        8.05      AR
# 1          75        6.71      CL
# 2         100        2.55      PH
# 3           0        3.29      AU
# 4         100        4.54      GL
# 5          89       12.88      AU
# 6           6        9.26      PF
# 7           6       11.63      AU
# 8          87        8.81      ZA
# 9         100        4.25      NZ

# %%
# Rearranging columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Ushuaia      AR -54.8000  -68.3000     28.06       100          75
# 1  Punta Arenas      CL -53.1500  -70.9167     33.91        69          75
# 2        Marawi      PH   7.9986  124.2928     67.64        91         100
# 3   Cootamundra      AU -34.6500  148.0333     48.94        54           0
# 4     Upernavik      GL  72.7868  -56.1549     31.60        93         100
# 5     Busselton      AU -33.6500  115.3333     51.08        68          89
# 6        Atuona      PF  -9.8000 -139.0333     79.56        64           6
# 7      Karratha      AU -20.7377  116.8463     67.82        69           6
# 8   East London      ZA -33.0153   27.9116     56.59        65          87
# 9       Mataura      NZ -46.1927  168.8643     49.48        98         100
#
#    Wind Speed Current Description
# 0        8.05       broken clouds
# 1        6.71       broken clouds
# 2        2.55     overcast clouds
# 3        3.29           clear sky
# 4        4.54     overcast clouds
# 5       12.88     overcast clouds
# 6        9.26           clear sky
# 7       11.63           clear sky
# 8        8.81     overcast clouds
# 9        4.25          light rain

# %%
# 8. Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
